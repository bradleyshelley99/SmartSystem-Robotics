# %%
import cv2
import math
math.cos(3.14)
# Out:
# -0.9999987317275395

# %%
#Put relative Path
img = cv2.imread('C:/Users/Brad/Pictures/xETSF.jpg')

#int i, j, x, y;
#double radius, theta;
#double trueX, trueY;
newimg = img
imgheight = img.shape[0]
imgwidth = img.shape[1]
p = 0.5
for i in range(0,imgheight-1):
    for j in range(0,imgwidth-1):
        radius = i
        theta = p*-j/(2*1)
        truex = radius * math.cos(theta)
        truey = radius * math.sin(theta)
        x = (truex + 1)
        y = 2- truey
        x = round(x)
        y = round(y)
        if(x >= 0 and x<= 2 and y>= 0 and y<= 2):
            newimg[i,j] = img[x,y]
        

            
        
        
        
#  #(i = 0; i < img.height; ++i)

#     for (j = 0; j < img.width; ++j)
#     {
#         radius = (double)i;
#         theta = p * (double)(-j) / (2 * length); // length is equals to 1
#             trueX = radius * cos(theta);
#         trueY = radius * sin(theta);
#         x = (int)(trueX + length);
#         y = length - (int)trueY;
#         if (x >= 0 && x <= (2 * length) && y >= 0 && y <= (2 * length))
#             image_result.at(i, j) = image.source.at(x, y);
#     }
# }





cv2.imshow('i',newimg)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Test for Camera
import numpy as np
import cv2

cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-db48bc6d3aa5> in <module>
#       6 while(True):
#       7     # Capture frame-by-frame
# ----> 8     ret, frame = cap.read()
#       9
#      10     # Our operations on the frame come here
#
# KeyboardInterrupt:
